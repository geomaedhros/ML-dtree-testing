# %% [markdown]
# # Sprint 11 - Lab 1. Víctor Guilló Seuthe

# %% [markdown]
# ### Importar librerías

# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import os
import re
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Importar datos

# %%
# directorio de trabajo
# os.chdir('P:\\repos\\03_edix\\S11_L1_entrega')

# %%
# importar datos
df = pd.read_csv("../data/MDA_churn_data.csv", encoding='latin-1')
df_bk = df.copy()

# %% [markdown]
# ### EDA

# %% [markdown]
# Muestra de datos y manipulación de tablas para la eliminación de campos innecesarios, y la creación de variables dicotómicas relevantes para su posterior modelado.

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6115  3831-YCPUO  Female              0     Yes        Yes      72
# 5483  5536-SLHPM  Female              0     Yes         No      55
# 2653  9481-WHGWY  Female              0     Yes        Yes      70
# 106   6728-DKUCO  Female              0     Yes        Yes      72
# 1392  1934-MKPXS    Male              0     Yes        Yes      33
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6115          Yes            No     Fiber optic                  Yes  ...
# 5483          Yes           Yes     Fiber optic                   No  ...
# 2653          Yes            No             DSL                  Yes  ...
# 106           Yes           Yes     Fiber optic                  Yes  ...
# 1392          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6115                  Yes                  Yes                  Yes
# 5483                  Yes                   No                   No
# 2653                   No                  Yes                  Yes
# 106                    No                   No                  Yes
# 1392  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6115                  Yes        Two year              Yes
# 5483                   No  Month-to-month              Yes
# 2653                  Yes        Two year               No
# 106                   Yes        One year              Yes
# 1392  No internet service        One year               No
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 6115  Credit card (automatic)         109.50        7854.9    No
# 5483         Electronic check          77.75       4458.15   Yes
# 2653  Credit card (automatic)          75.35       5437.75    No
# 106          Electronic check         104.15       7303.05    No
# 1392  Credit card (automatic)          20.10        620.55    No
#
# [5 rows x 21 columns]

# %%
# mostrar tipos de datos
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# comprobar falta de datos
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# contar filas con campos vacios en TotalCharges
df[df['TotalCharges'] == ' '].count()
# Out:
# customerID          11
# gender              11
# SeniorCitizen       11
# Partner             11
# Dependents          11
# tenure              11
# PhoneService        11
# MultipleLines       11
# InternetService     11
# OnlineSecurity      11
# OnlineBackup        11
# DeviceProtection    11
# TechSupport         11
# StreamingTV         11
# StreamingMovies     11
# Contract            11
# PaperlessBilling    11
# PaymentMethod       11
# MonthlyCharges      11
# TotalCharges        11
# Churn               11
# dtype: int64

# %%
# eliminar filas con campos vacios en TotalCharges
df = df[df['TotalCharges'] != ' ']

# %%
# 0 numericos, 1 boolean, 2 categoricos, otros binarios 3

features = [('gender', 3),
            ('SeniorCitizen', 3), 
            ('Partner', 1),
            ('Dependents', 1),
            ('tenure', 0),
            ('PhoneService', 1),
            ('MultipleLines', 1),
            ('InternetService', 2),
            ('OnlineSecurity', 1),
            ('OnlineBackup', 1),
            ('DeviceProtection', 1),
            ('TechSupport', 1),
            ('StreamingTV', 1), 
            ('StreamingMovies', 1),
            ('Contract', 2),
            ('PaperlessBilling', 1),
            ('PaymentMethod', 0),
            ('MonthlyCharges', 0),
            ('TotalCharges', 0),
            ('Churn', 1)
           ]

# %%
# modificamos servicios no existentes a valor "No"
df = df.replace(to_replace=r'^No.*service$', value="No", regex=True)

# modificamos tipo de datos de TotalCharges
df['TotalCharges'] = df['TotalCharges'].astype(float)

# modificamos valores Yes/No a 1/0
for feature in features:
    if feature[1] == 1:
        df[feature[0]] = df[feature[0]].map({"Yes": 1, "No": 0})

# %%
# almacenamos listas de categorias de servicios, pagos y contratos
InternetServices = list(df['InternetService'].unique())
for i, j in enumerate(InternetServices):
    InternetServices[i] = (j.split()[0]+"_Inet", j)

PaymentMethods =  list(df['PaymentMethod'].unique())
for i, j in enumerate(PaymentMethods):
    PaymentMethods[i] = (PaymentMethods[i].split()[0]+"Pay", j)

Contracts =  list(df['Contract'].unique())
for i, j in enumerate(Contracts):
    Contracts[i] = (j.replace("-"," ").split()[0]+"_period", j)

# %%
# one hot encoding
for feature in InternetServices:
    df[feature[0]] = (df['InternetService']==feature[1]).astype(int)

for feature in PaymentMethods:
    df[feature[0]] = (df['PaymentMethod']==feature[1]).astype(int)
       
for feature in Contracts:
    df[feature[0]] = (df['Contract']==feature[1]).astype(int)

# %%
# descartar posibles valores no binarios en gender
df[(df['gender'] != 'Male') & (df['gender'] != 'Female')]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn, DSL_Inet, Fiber_Inet, No_Inet, ElectronicPay, MailedPay, BankPay, CreditPay, Month_period, One_period, Two_period]
# Index: []
#
# [0 rows x 31 columns]

# %%
# encode female / not female
df['Female'] = (df['gender']=="Female").astype(int)

# %%
# eliminar columnas categorizadas o innecesarias
df = df.drop(['customerID', 'gender', 'InternetService', 'Contract', 'PaymentMethod'], axis = 1).reset_index(drop=True)

# %%
df.sample(10)
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 4842              0        0           0      54             1              0
# 695               0        1           0      72             1              1
# 6068              0        1           0      62             1              1
# 1008              0        1           1      71             0              0
# 6843              0        0           0       2             1              0
# 1876              0        0           0      26             0              0
# 4964              0        1           0      71             1              1
# 4784              1        1           0      65             1              1
# 5296              0        1           0      43             1              0
# 567               0        0           0      35             1              1
#
#       OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  ...  \
# 4842               1             1                 0            0  ...
# 695                0             1                 1            1  ...
# 6068               1             1                 1            1  ...
# 1008               1             1                 0            1  ...
# 6843               0             0                 0            0  ...
# 1876               1             1                 0            0  ...
# 4964               0             0                 0            0  ...
# 4784               0             1                 1            0  ...
# 5296               1             0                 1            1  ...
# 567                0             0                 1            0  ...
#
#       Fiber_Inet  No_Inet  ElectronicPay  MailedPay  BankPay  CreditPay  \
# 4842           1        0              0          0        0          1
# 695            0        0              0          0        1          0
# 6068           1        0              0          1        0          0
# 1008           0        0              0          1        0          0
# 6843           0        1              0          1        0          0
# 1876           0        0              0          0        1          0
# 4964           0        1              0          0        0          1
# 4784           1        0              1          0        0          0
# 5296           0        0              1          0        0          0
# 567            1        0              1          0        0          0
#
#       Month_period  One_period  Two_period  Female
# 4842             0           1           0       1
# 695              0           0           1       0
# 6068             0           0           1       1
# 1008             0           0           1       1
# 6843             1           0           0       0
# 1876             1           0           0       0
# 4964             0           0           1       1
# 4784             0           1           0       1
# 5296             0           0           1       1
# 567              1           0           0       1
#
# [10 rows x 27 columns]

# %%
df.dtypes
# Out:
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# PaperlessBilling      int64
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# DSL_Inet              int32
# Fiber_Inet            int32
# No_Inet               int32
# ElectronicPay         int32
# MailedPay             int32
# BankPay               int32
# CreditPay             int32
# Month_period          int32
# One_period            int32
# Two_period            int32
# Female                int32
# dtype: object

# %% [markdown]
# #### Gráficos de análisis

# %% [markdown]
# ##### Correlación entre variables (features)

# %%
# formats
sns.axes_style("whitegrid")

# crear figura
fig, ax = plt.subplots(figsize=(12,12)) 

# plot heatmap
corr_data = df.corr()
sns.heatmap(corr_data,
            vmin=-1,
            vmax=1,
            square=True,
            cmap="YlGnBu",
            linewidths=0.1,
            annot=True,
            annot_kws={"fontsize":7, }
        )
# Out:
# <AxesSubplot:>

# %%
# visualizacion sesgo churn rate
pd.DataFrame(df['Churn'].value_counts())
# Out:
#    Churn
# 0   5163
# 1   1869

# %%
# Clasificadores kNN
knn_models = {} # diccionario de resultados de modelo
X = df.drop('Churn', axis=1)   # features
y = df['Churn']                # target
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                   test_size = 0.2,     # 20% test
                                                   random_state = 7,   # seed
                                                   stratify = y)       # conservar proporciones train/test
for k in range(4, 12):
    knn = KNeighborsClassifier(n_neighbors=k)        # instanciar Clasif kNN 
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    knn_models[k] = [knn, train_score, test_score]   # agregar modelo k a diccionario

# %%
df_models = pd.DataFrame(knn_models).transpose().set_axis(['Model', 'Train', 'Test'], axis=1)

# %%
df_models
# Out:
#                               Model_Name     Train      Test
# 4    KNeighborsClassifier(n_neighbors=4)  0.832889  0.774698
# 5                 KNeighborsClassifier()    0.8256  0.764748
# 6    KNeighborsClassifier(n_neighbors=6)  0.816533  0.781095
# 7    KNeighborsClassifier(n_neighbors=7)  0.817422  0.778252
# 8    KNeighborsClassifier(n_neighbors=8)  0.812267   0.78607
# 9    KNeighborsClassifier(n_neighbors=9)  0.812267  0.790334
# 10  KNeighborsClassifier(n_neighbors=10)  0.810489  0.792466
# 11  KNeighborsClassifier(n_neighbors=11)  0.812622  0.791756

# %%
g = sns.FacetGrid(df_model, col="Model", hue=["Train", "Test"], col_wrap=5)
g.map(sns.lineplot, "Cycle","Fluo", "WellID")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GEOMAE~1\AppData\Local\Temp/ipykernel_14172/1368094300.py in <module>
#       1 fig, axs = plt.subplots(2, 4)
# ----> 2 axs[0, 0].plot(x, y)
#       3 axs[0, 0].set_title('Axis [0, 0]')
#       4 axs[0, 1].plot(x, y, 'tab:orange')
#       5 axs[0, 1].set_title('Axis [0, 1]')
#
# NameError: name 'x' is not defined
